# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanSebastianSantos/PROGCOM-A/blob/main/Clase_8_POO_Programacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Floristeria
#1. Conjunto de flores, se elige aleatoriamente una cantidad
import random

flores=["tulipan","lirio","rosa","dahlia","margarita","girasol","clavel","geranio"]
seleccion=random.sample(flores,3)
seleccion
# Out:
# ['rosa', 'margarita', 'tulipan']

# %%
def inventario():
  flores=["tulipan","lirio","rosa","dahlia","margarita","girasol","clavel","geranio"]
  seleccion=random.sample(flores,3)

  inventario={
      flor:{
          "precio":random.randint(2000,6000),
          "cantidad":random.randint(10,50),
          "vendidas":0
      } for flor in seleccion
      }
  return inventario

# %%
inventario()
# Out:
# {'geranio': {'precio': 2833, 'cantidad': 21, 'vendidas': 0},
#  'rosa': {'precio': 4288, 'cantidad': 23, 'vendidas': 0},
#  'tulipan': {'precio': 5387, 'cantidad': 46, 'vendidas': 0}}

# %%
flor=inventario()
flor.items()

# %%
def menu(inventario):
  print("\n---MENU DE FLORES DISPONIBLES FLORISTERIA CARLITOS---")
  for flor,datos in inventario.items():
    print(f"{flor}:${datos['precio']} cant: {datos['cantidad']} disponible")
  print("------------------------------------------")

# %%
menu(inventario())
# Out:
# ---MENU DE FLORES DISPONIBLES FLORISTERIA CARLITOS---
# girasol:$3971 cant: 45 disponible
# margarita:$5789 cant: 47 disponible
# dahlia:$2006 cant: 36 disponible
# ------------------------------------------

# %%
def ventas(inventario, flor, cantidad, total_ganado):
  if flor not in inventario:
    print(f"{flor} no se encuentra a la venta")
    return total_ganado
  datos = inventario[flor]
  if cantidad > datos["cantidad"]:
    print(f"lo siento, no tenemos la cantidad requerida")
    return total_ganado

  #Realizando la venta
  datos["cantidad"] -= cantidad
  datos["vendidas"] += cantidad
  venta = datos["precio"] * cantidad
  total_ganado += venta
  print(f"Vendidas: {cantidad} de {flor} por un total de ${venta}")

  #Si se acaba, eliminamos la flor
  if datos["cantidad"] == 0:
    print(f"{flor} ha sido eliminada del inventario")
    del inventario[flor]
  return total_ganado

# %%
def cerrar_tienda(inventario_inicial, inventario_final,total_ganado):
  print("\n---Tienda Cerrada---")
  #Combinar el inventario inicial con el final para saber cuantas se vendio
  flores_vendidad={}
  for flor,datos in inventario_inicial.items():
    cantidad_final=inventario_final.get(flor,{"cantidad":0})["cantidad"]
    vendidas=datos["cantidad"]-cantidad_final
    flores_vendidas[flor]=vendidas

    #Determinar cuales fueron las mas vendidas
    mas_vendidas=max(flores_vendidas,key=flores_vendidas.get)
    menos_vendidas=min(flores_vendidas,key=flores_vendidas.get)

    print(f"La flor mas vendida fue{mas_vendida}:{flores_vendidas[mas_vendida]} unidades")
    print(f"Flor menos vendida fue {menos_vendida}:{flores_vendidas[menos_vendida]} unidades")

# %%
flor

# %%
total_ganado=0
total_ganado=ventas(flor,"rosa",10,total_ganado)
total_ganado=ventas(flor,"clavel",18,total_ganado)
total_ganado=ventas (flor,"margarita",80,total_ganado)

# %%
flor = inventario() # Define flor by calling inventario()
menu(flor)
# Out:
# ---MENU DE FLORES DISPONIBLES FLORISTERIA CARLITOS---
# geranio:$5092 cant: 15 disponible
# rosa:$3812 cant: 32 disponible
# tulipan:$4017 cant: 39 disponible
# ------------------------------------------
